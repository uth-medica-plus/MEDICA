# %% [markdown]
# 1. Import bibliotek

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# 2. Przygotowanie danych

# %%
# Metraż (m²)
X = np.array([30, 35, 40, 45, 50, 55, 60, 65, 70, 80]).reshape(-1, 1)

# Cena (w tys. zł)
y = np.array([210, 230, 250, 270, 300, 330, 360, 390, 420, 480])

# %% [markdown]
# 3. Trenowanie modelu regresji liniowej

# %%
model = LinearRegression()
model.fit(X, y)

print("Współczynnik nachylenia (a):", model.coef_[0])
print("Wyraz wolny (b):", model.intercept_)
# Out:
# Współczynnik nachylenia (a): 5.4891774891774885
# Wyraz wolny (b): 33.07359307359309

# %%
4. Ocena jakości modelu

# %%
y_pred = model.predict(X)
r2 = r2_score(y, y_pred)

print("R² modelu:", r2)
# Out:
# R² modelu: 0.9937574323639429

# %% [markdown]
# 5. Wizualizacja danych i linii regresji

# %%
plt.figure(figsize=(10,6))
plt.scatter(X, y, color='blue', label='Dane rzeczywiste')
plt.plot(X, y_pred, color='red', label='Linia regresji')
plt.xlabel("Powierzchnia (m²)")
plt.ylabel("Cena (tys. zł)")
plt.title("Regresja liniowa: cena mieszkania vs metraż")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 6. Przewidywanie ceny dla nowego metrażu

# %%
nowy_metraz = 52
przewidywana_cena = model.predict([[nowy_metraz]])

print(f"Przewidywana cena dla {nowy_metraz} m²: {przewidywana_cena[0]:.2f} tys. zł")
# Out:
# Przewidywana cena dla 52 m²: 318.51 tys. zł

# %%
nowy_metraz = 25
przewidywana_cena = model.predict([[nowy_metraz]])

print(f"Przewidywana cena dla {nowy_metraz} m²: {przewidywana_cena[0]:.2f} tys. zł")
# Out:
# Przewidywana cena dla 25 m²: 170.30 tys. zł
